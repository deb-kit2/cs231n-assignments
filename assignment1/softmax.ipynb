# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/assignment1")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.347922
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 1.257343 analytic: 1.257343, relative error: 7.811989e-08
# numerical: 1.189913 analytic: 1.189913, relative error: 5.744894e-09
# numerical: -1.793077 analytic: -1.793077, relative error: 4.266487e-09
# numerical: 3.242558 analytic: 3.242558, relative error: 1.467944e-08
# numerical: 3.111560 analytic: 3.111560, relative error: 2.965510e-08
# numerical: -0.502321 analytic: -0.502321, relative error: 1.398807e-07
# numerical: 2.017394 analytic: 2.017394, relative error: 4.091111e-08
# numerical: -0.567405 analytic: -0.567405, relative error: 7.242130e-08
# numerical: 2.155211 analytic: 2.155211, relative error: 3.456353e-08
# numerical: -0.437846 analytic: -0.437846, relative error: 1.708700e-07
# numerical: 3.347910 analytic: 3.347910, relative error: 2.369835e-08
# numerical: -1.198305 analytic: -1.198305, relative error: 4.985604e-08
# numerical: 0.585010 analytic: 0.585010, relative error: 7.508093e-08
# numerical: 0.732085 analytic: 0.732084, relative error: 1.077176e-07
# numerical: 1.498834 analytic: 1.498834, relative error: 2.138669e-08
# numerical: 2.058661 analytic: 2.058661, relative error: 1.281380e-08
# numerical: -1.740648 analytic: -1.740648, relative error: 9.112629e-09
# numerical: -1.047048 analytic: -1.047048, relative error: 5.006267e-08
# numerical: 0.518171 analytic: 0.518171, relative error: 5.399458e-08
# numerical: -0.524407 analytic: -0.524408, relative error: 7.255199e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.347922e+00 computed in 0.107589s
# vectorized loss: 2.347922e+00 computed in 0.012256s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 2e-6, 2.5e-6]
regularization_strengths = [1e3, 1e4, 2e4, 2.5e4, 3e4, 3.5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
model = Softmax()
for rate in learning_rates:
  for reg in regularization_strengths:
    hist = model.train(X_train, y_train, learning_rate = rate, reg = reg, num_iters = 1000, verbose = True)
    pred_t = model.predict(X_train)
    pred_v = model.predict(X_val)

    acc_t = np.mean(pred_t==y_train)
    acc_v = np.mean(pred_v==y_val)

    results[(rate, reg)] = (acc_t, acc_v)

    if acc_v > best_val:
      best_val = acc_v
      best_softmax = model
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1000: loss 36.812872
# iteration 100 / 1000: loss 33.752021
# iteration 200 / 1000: loss 32.253935
# iteration 300 / 1000: loss 30.837532
# iteration 400 / 1000: loss 29.481378
# iteration 500 / 1000: loss 27.976919
# iteration 600 / 1000: loss 26.908048
# iteration 700 / 1000: loss 25.931920
# iteration 800 / 1000: loss 24.980354
# iteration 900 / 1000: loss 23.907573
# iteration 0 / 1000: loss 208.111921
# iteration 100 / 1000: loss 139.950396
# iteration 200 / 1000: loss 94.224173
# iteration 300 / 1000: loss 63.785149
# iteration 400 / 1000: loss 43.308329
# iteration 500 / 1000: loss 29.662672
# iteration 600 / 1000: loss 20.526485
# iteration 700 / 1000: loss 14.433432
# iteration 800 / 1000: loss 10.302652
# iteration 900 / 1000: loss 7.516000
# iteration 0 / 1000: loss 9.539530
# iteration 100 / 1000: loss 5.404215
# iteration 200 / 1000: loss 3.594180
# iteration 300 / 1000: loss 2.691349
# iteration 400 / 1000: loss 2.341182
# iteration 500 / 1000: loss 2.208866
# iteration 600 / 1000: loss 2.122587
# iteration 700 / 1000: loss 2.082828
# iteration 800 / 1000: loss 2.103469
# iteration 900 / 1000: loss 2.037599
# iteration 0 / 1000: loss 2.091955
# iteration 100 / 1000: loss 2.135517
# iteration 200 / 1000: loss 2.138906
# iteration 300 / 1000: loss 2.108030
# iteration 400 / 1000: loss 2.101391
# iteration 500 / 1000: loss 2.103058
# iteration 600 / 1000: loss 2.045718
# iteration 700 / 1000: loss 2.060948
# iteration 800 / 1000: loss 2.049682
# iteration 900 / 1000: loss 2.031703
# iteration 0 / 1000: loss 2.111890
# iteration 100 / 1000: loss 2.113546
# iteration 200 / 1000: loss 2.107688
# iteration 300 / 1000: loss 2.134897
# iteration 400 / 1000: loss 2.081409
# iteration 500 / 1000: loss 2.086033
# iteration 600 / 1000: loss 2.105943
# iteration 700 / 1000: loss 2.056416
# iteration 800 / 1000: loss 2.142056
# iteration 900 / 1000: loss 2.110141
# iteration 0 / 1000: loss 2.128404
# iteration 100 / 1000: loss 2.120775
# iteration 200 / 1000: loss 2.172411
# iteration 300 / 1000: loss 2.068195
# iteration 400 / 1000: loss 2.081889
# iteration 500 / 1000: loss 2.088191
# iteration 600 / 1000: loss 2.100595
# iteration 700 / 1000: loss 2.091482
# iteration 800 / 1000: loss 2.130387
# iteration 900 / 1000: loss 2.100635
# iteration 0 / 1000: loss 2.015416
# iteration 100 / 1000: loss 1.963092
# iteration 200 / 1000: loss 1.795222
# iteration 300 / 1000: loss 1.884683
# iteration 400 / 1000: loss 1.963359
# iteration 500 / 1000: loss 1.825071
# iteration 600 / 1000: loss 1.889354
# iteration 700 / 1000: loss 1.871834
# iteration 800 / 1000: loss 1.899922
# iteration 900 / 1000: loss 1.972678
# iteration 0 / 1000: loss 2.460775
# iteration 100 / 1000: loss 2.014319
# iteration 200 / 1000: loss 2.011331
# iteration 300 / 1000: loss 2.070510
# iteration 400 / 1000: loss 1.976901
# iteration 500 / 1000: loss 2.079039
# iteration 600 / 1000: loss 1.994112
# iteration 700 / 1000: loss 2.005867
# iteration 800 / 1000: loss 1.965893
# iteration 900 / 1000: loss 2.072318
# iteration 0 / 1000: loss 2.209724
# iteration 100 / 1000: loss 2.091124
# iteration 200 / 1000: loss 2.085939
# iteration 300 / 1000: loss 2.109331
# iteration 400 / 1000: loss 2.121862
# iteration 500 / 1000: loss 2.103733
# iteration 600 / 1000: loss 2.057553
# iteration 700 / 1000: loss 2.048619
# iteration 800 / 1000: loss 2.140895
# iteration 900 / 1000: loss 2.072667
# iteration 0 / 1000: loss 2.124420
# iteration 100 / 1000: loss 2.175339
# iteration 200 / 1000: loss 2.080798
# iteration 300 / 1000: loss 2.119368
# iteration 400 / 1000: loss 2.112993
# iteration 500 / 1000: loss 2.209962
# iteration 600 / 1000: loss 2.061960
# iteration 700 / 1000: loss 2.123026
# iteration 800 / 1000: loss 2.078777
# iteration 900 / 1000: loss 2.118485
# iteration 0 / 1000: loss 2.118439
# iteration 100 / 1000: loss 2.103982
# iteration 200 / 1000: loss 2.122762
# iteration 300 / 1000: loss 2.139444
# iteration 400 / 1000: loss 2.131842
# iteration 500 / 1000: loss 2.127654
# iteration 600 / 1000: loss 2.167512
# iteration 700 / 1000: loss 2.150650
# iteration 800 / 1000: loss 2.103978
# iteration 900 / 1000: loss 2.155445
# iteration 0 / 1000: loss 2.100260
# iteration 100 / 1000: loss 2.122829
# iteration 200 / 1000: loss 2.137414
# iteration 300 / 1000: loss 2.167625
# iteration 400 / 1000: loss 2.146586
# iteration 500 / 1000: loss 2.154727
# iteration 600 / 1000: loss 2.060708
# iteration 700 / 1000: loss 2.114794
# iteration 800 / 1000: loss 2.116008
# iteration 900 / 1000: loss 2.103211
# iteration 0 / 1000: loss 2.040942
# iteration 100 / 1000: loss 1.918440
# iteration 200 / 1000: loss 1.718160
# iteration 300 / 1000: loss 1.809865
# iteration 400 / 1000: loss 1.853240
# iteration 500 / 1000: loss 1.893867
# iteration 600 / 1000: loss 1.812227
# iteration 700 / 1000: loss 1.870479
# iteration 800 / 1000: loss 1.834441
# iteration 900 / 1000: loss 1.851891
# iteration 0 / 1000: loss 2.431484
# iteration 100 / 1000: loss 2.052709
# iteration 200 / 1000: loss 2.061191
# iteration 300 / 1000: loss 2.110566
# iteration 400 / 1000: loss 2.074426
# iteration 500 / 1000: loss 2.100076
# iteration 600 / 1000: loss 2.050005
# iteration 700 / 1000: loss 2.089863
# iteration 800 / 1000: loss 2.137236
# iteration 900 / 1000: loss 1.972495
# iteration 0 / 1000: loss 2.154896
# iteration 100 / 1000: loss 2.175548
# iteration 200 / 1000: loss 2.166389
# iteration 300 / 1000: loss 2.170687
# iteration 400 / 1000: loss 2.145917
# iteration 500 / 1000: loss 2.168000
# iteration 600 / 1000: loss 2.077575
# iteration 700 / 1000: loss 2.122938
# iteration 800 / 1000: loss 2.100794
# iteration 900 / 1000: loss 2.155375
# iteration 0 / 1000: loss 2.173577
# iteration 100 / 1000: loss 2.141114
# iteration 200 / 1000: loss 2.113641
# iteration 300 / 1000: loss 2.147829
# iteration 400 / 1000: loss 2.224697
# iteration 500 / 1000: loss 2.131851
# iteration 600 / 1000: loss 2.144590
# iteration 700 / 1000: loss 2.137448
# iteration 800 / 1000: loss 2.146371
# iteration 900 / 1000: loss 2.177182
# iteration 0 / 1000: loss 2.166413
# iteration 100 / 1000: loss 2.124065
# iteration 200 / 1000: loss 2.103211
# iteration 300 / 1000: loss 2.118398
# iteration 400 / 1000: loss 2.107356
# iteration 500 / 1000: loss 2.099274
# iteration 600 / 1000: loss 2.128884
# iteration 700 / 1000: loss 2.216246
# iteration 800 / 1000: loss 2.159650
# iteration 900 / 1000: loss 2.183025
# iteration 0 / 1000: loss 2.139338
# iteration 100 / 1000: loss 2.140636
# iteration 200 / 1000: loss 2.168705
# iteration 300 / 1000: loss 2.209815
# iteration 400 / 1000: loss 2.152835
# iteration 500 / 1000: loss 2.179404
# iteration 600 / 1000: loss 2.168537
# iteration 700 / 1000: loss 2.144463
# iteration 800 / 1000: loss 2.187567
# iteration 900 / 1000: loss 2.129021
# lr 1.000000e-07 reg 1.000000e+03 train accuracy: 0.231673 val accuracy: 0.223000
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.346306 val accuracy: 0.351000
# lr 1.000000e-07 reg 2.000000e+04 train accuracy: 0.337510 val accuracy: 0.348000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.329490 val accuracy: 0.345000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.328571 val accuracy: 0.342000
# lr 1.000000e-07 reg 3.500000e+04 train accuracy: 0.318776 val accuracy: 0.333000
# lr 2.000000e-06 reg 1.000000e+03 train accuracy: 0.397143 val accuracy: 0.400000
# lr 2.000000e-06 reg 1.000000e+04 train accuracy: 0.336939 val accuracy: 0.356000
# lr 2.000000e-06 reg 2.000000e+04 train accuracy: 0.295510 val accuracy: 0.297000
# lr 2.000000e-06 reg 2.500000e+04 train accuracy: 0.289878 val accuracy: 0.306000
# lr 2.000000e-06 reg 3.000000e+04 train accuracy: 0.299347 val accuracy: 0.315000
# lr 2.000000e-06 reg 3.500000e+04 train accuracy: 0.284980 val accuracy: 0.307000
# lr 2.500000e-06 reg 1.000000e+03 train accuracy: 0.393918 val accuracy: 0.376000
# lr 2.500000e-06 reg 1.000000e+04 train accuracy: 0.335102 val accuracy: 0.340000
# lr 2.500000e-06 reg 2.000000e+04 train accuracy: 0.301449 val accuracy: 0.282000
# lr 2.500000e-06 reg 2.500000e+04 train accuracy: 0.290020 val accuracy: 0.294000
# lr 2.500000e-06 reg 3.000000e+04 train accuracy: 0.300245 val accuracy: 0.302000
# lr 2.500000e-06 reg 3.500000e+04 train accuracy: 0.266633 val accuracy: 0.275000
# best validation accuracy achieved during cross-validation: 0.400000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.265000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
